# %%
num16 = 0.4 * (((0.16 * (3.2 - (3 / 40))) + ((((2 + 3 / 11)) * 4.125) / (3 + 3 / 4))) / (((5 + 1 / 6) * 0.3) - ((0/3 * 4.5)) + (1 / 3 * 0.3)))
print(num16)
# Out:
# 0.7272727272727271

# %%
num15 = 5.75 / 2.5 * 100
print(num15)
# Out:
# 229.99999999999997

# %%
num14 = (((9 - (5 + 3 / 8)) * ((4 + 5 / 12) - (4 / (2 + 2 / 3)))) + (((3 / 10 - (0.5 / 4)) * (4 / 7))))/ (1 / 24 + (0.25 / (13 + 1 / 3)))
print(num14)
# Out:
# 176.65517241379314

# %%
num13 = (11 + 2 / 5)+ (7 + 1 / 2) * ((285.6 / 14 ) - (1 + 23 / 30) + (13 / 50))/ (24.4 - 10.23)
print(num13)
# Out:
# 21.400000000000006

# %%
num12 = ((((2 + 3 / 4) / 1.1 ) + (3 + 1 /3)) / ((2.5 - (0.4 * (3 + (1/3)))))) / (5 / 7) - (((2 + (1 / 6)) + 4.5) * 0.375) / ((2.75 - (1 + 1/ 2)))
print(num12)
# Out:
# 5.000000000000001

# %%
num11 = ((((6 + 7 / 12) - (3 + 17 / 36)) * 2.5) - ((4 + 1 / 3) / 0.65))/ ((4 / (1 /4) - 0.5))
print(num11)
# Out:
# 0.07168458781362004

# %%
temp = 90
num10 = (temp - 32) * 5 / 9
print(num10)
# Out:
# 32.22222222222222

# %%
a = pos_num = (int(6))
b = neg_num = (int(-7))
num9 = abs(a)+abs(b)
print(num9)
# Out:
# 13

# %%
a = 3
b = 4
num8 = c = (a**2 + b**2)**0.5
print(c)
# Out:
# 5.0

# %%
import math
number1 = float(800.39)
number2 = float(700.41)
num7 = math.ceil(number1 - number2)
print(num7)
# Out:
# 100

# %%
import math
number1 = float_num = 6.6
number2 = float_num = 1.8
num6 = math.floor(number1 - number2)
print(num6)
# Out:
# 4

# %%
a = float_num = 2
num5 = a**3 / 2
round (num5 , 1)
# Out:
# 4.0

# %%
a = float_num1 = 3.5
b = float_num2 = 6.7
c = float_num3 = 8.9
num4 = a * b / c
print(num4)
# Out:
# 2.634831460674157

# %%
number1 = int(800)
number2 = int(700)
num3 = number1 % number2
print(num3)
# Out:
# 100

# %%
number1 = int(40)
number2 = int(30)
num2 =int(number1 / number2)
print(num2)
# Out:
# 1

# %%
number1 = 200
number2=300
num1 = number1 + number2
print(num1)
# Out:
# 500
